# %%
import csv
import codecs
import pandas as pd
from os import walk
import re
import os
import pprint
import datetime
import numpy as np
import matplotlib.pyplot as plt
import emoji
import seaborn as sns
import stats
from scipy import stats

# %%
current_path = os.getcwd().replace("\\", "/") + "/"
print(current_path)
df = pd.read_csv(current_path + "dataset.csv",sep = ',')
# Out:
# D:/Users/martin/Desktop/repos/social-media-analytics/

# %%
var1="likes"
var2="followers"
sns.regplot(df[var2],df[var1])
slope, intercept, r_value, p_value, std_err = stats.linregress(df[var2],df[var1])
print("r2=", r_value**2, "pendiente=", slope)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# r2= 0.5127003429645546 pendiente= 0.029917662541761994

# %%
var1="comments"
var2="followers"
sns.regplot(df[var2],df[var1])
slope, intercept, r_value, p_value, std_err = stats.linregress(df[var2],df[var1])
print("r2=", r_value**2, "pendiente=", slope)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# r2= 0.09296570905170747 pendiente= 0.0002974012339438083

# %%
var1="likes"
var2="followings"
sns.regplot(df[var2],df[var1])
slope, intercept, r_value, p_value, std_err = stats.linregress(df[var2],df[var1])
print("r2=", r_value**2, "pendiente=", slope)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# r2= 0.00036425204955227165 pendiente= -0.2689558019649748

# %%
var1="comments"
var2="followings"
sns.regplot(df[var2],df[var1])
slope, intercept, r_value, p_value, std_err = stats.linregress(df[var2],df[var1])
print("r2=", r_value**2, "pendiente=", slope)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# r2= 2.1018205032643496e-05 pendiente= -0.0015082149638227973
